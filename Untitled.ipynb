# %%
import os
import sys
sys.path
import numpy as np
np.__path__
import pandas as pd
pd.__path__
import seaborn as sns #visualisation
sns.__path__
import matplotlib as plt #visualisation
plt.__path__
# importing matplotlib module 
from matplotlib import pyplot as plt 
get_ipython().run_line_magic('matplotlib', 'inline')
sns.set(color_codes=True)

# %%
df = pd.read_csv("C:\\Users\\HP\\Desktop\\ITSalarySurveyEU.csv")
df
# Out:
#      Unnamed: 0  unnamed:_0   timestamp  age gender          city  \
# 0             0           0  24-11-2020   26   Male        Munich
# 1             1           1  24-11-2020   29   Male        Berlin
# 2             2           2  24-11-2020   32   Male        Berlin
# 3             3           3  24-11-2020   34   Male        Berlin
# 4             4           4  24-11-2020   38   Male        Berlin
# ..          ...         ...         ...  ...    ...           ...
# 489         489         489  12-01-2021   37   Male        Berlin
# 490         490         490  16-01-2021   32   Male        Munich
# 491         491         491  18-01-2021   31   Male        Berlin
# 492         492         492  19-01-2021   26   Male  SaarbrÃ¼cken
# 493         493         493  19-01-2021   26   Male        Berlin
#
#                position  total_years_of_experience  \
# 0     Software Engineer                        5.0
# 1     Software Engineer                       12.0
# 2                DevOps                        5.0
# 3      Mobile Developer                       11.0
# 4             Team Lead                       18.0
# ..                  ...                        ...
# 489    Mobile Developer                       15.0
# 490   Software Engineer                       10.0
# 491   Backend Developer                        9.0
# 492  Frontend Developer                        7.0
# 493              DevOps                        2.0
#
#      years_of_experience_in_germany seniority_level  ... bonus+stocks  \
# 0                               3.0          Senior  ...       5000.0
# 1                               6.0            Lead  ...     120000.0
# 2                               1.0          Senior  ...       5000.0
# 3                               5.0            Lead  ...      80000.0
# 4                               4.0            Lead  ...       4000.0
# ..                              ...             ...  ...          ...
# 489                             5.0          Senior  ...       1000.0
# 490                             5.0            Head  ...          NaN
# 491                             5.0          Senior  ...      72000.0
# 492                             7.0          Middle  ...      40950.0
# 493                             2.0          Middle  ...       6500.0
#
#     annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 0                                              75000.0
# 1                                             100000.0
# 2                                              76000.0
# 3                                              75000.0
# 4                                              80000.0
# ..                                                 ...
# 489                                            83000.0
# 490                                            80000.0
# 491                                            70000.0
# 492                                            33800.0
# 493                                            40000.0
#
#      bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 0                                              10000.0
# 1                                             100000.0
# 2                                               5000.0
# 3                                              75000.0
# 4                                               2000.0
# ..                                                 ...
# 489                                             3500.0
# 490                                                NaN
# 491                                            72000.0
# 492                                            36400.0
# 493                                                NaN
#
#      vacation_days           employment_status   contract_duration  \
# 0               30          Full-time employee  Unlimited contract
# 1               30  Self-employed (freelancer)  Temporary contract
# 2               30          Full-time employee  Unlimited contract
# 3               28          Full-time employee  Unlimited contract
# 4               28          Full-time employee  Unlimited contract
# ..             ...                         ...                 ...
# 489             29          Full-time employee  Unlimited contract
# 490             24          Full-time employee  Unlimited contract
# 491             26          Full-time employee  Unlimited contract
# 492             27          Full-time employee  Unlimited contract
# 493             30          Full-time employee  Unlimited contract
#
#     main_language company_size company_type lost_job
# 0         English       51-100      Product       No
# 1         English     101-1000      Product      Yes
# 2         English       Nov-50      Startup       No
# 3         English     101-1000      Product       No
# 4         English     101-1000      Product      Yes
# ..            ...          ...          ...      ...
# 489       English     101-1000      Product       No
# 490       English       Nov-50      Startup       No
# 491       English       51-100      Product      Yes
# 492        German     101-1000      Product       No
# 493       English       51-100      Startup       No
#
# [494 rows x 23 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0  unnamed:_0   timestamp  age gender    city           position  \
# 0           0           0  24-11-2020   26   Male  Munich  Software Engineer
# 1           1           1  24-11-2020   29   Male  Berlin  Software Engineer
# 2           2           2  24-11-2020   32   Male  Berlin             DevOps
# 3           3           3  24-11-2020   34   Male  Berlin   Mobile Developer
# 4           4           4  24-11-2020   38   Male  Berlin          Team Lead
#
#    total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 0                        5.0                             3.0          Senior
# 1                       12.0                             6.0            Lead
# 2                        5.0                             1.0          Senior
# 3                       11.0                             5.0            Lead
# 4                       18.0                             4.0            Lead
#
#    ... bonus+stocks  \
# 0  ...       5000.0
# 1  ...     120000.0
# 2  ...       5000.0
# 3  ...      80000.0
# 4  ...       4000.0
#
#   annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 0                                            75000.0
# 1                                           100000.0
# 2                                            76000.0
# 3                                            75000.0
# 4                                            80000.0
#
#    bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 0                                            10000.0
# 1                                           100000.0
# 2                                             5000.0
# 3                                            75000.0
# 4                                             2000.0
#
#    vacation_days           employment_status   contract_duration  \
# 0             30          Full-time employee  Unlimited contract
# 1             30  Self-employed (freelancer)  Temporary contract
# 2             30          Full-time employee  Unlimited contract
# 3             28          Full-time employee  Unlimited contract
# 4             28          Full-time employee  Unlimited contract
#
#   main_language company_size company_type lost_job
# 0       English       51-100      Product       No
# 1       English     101-1000      Product      Yes
# 2       English       Nov-50      Startup       No
# 3       English     101-1000      Product       No
# 4       English     101-1000      Product      Yes
#
# [5 rows x 23 columns]

# %%
df.tail(5)
# Out:
#      Unnamed: 0   timestamp  age gender          city            position  \
# 489         489  12-01-2021   37   Male        Berlin    Mobile Developer
# 490         490  16-01-2021   32   Male        Munich   Software Engineer
# 491         491  18-01-2021   31   Male        Berlin   Backend Developer
# 492         492  19-01-2021   26   Male  SaarbrÃ¼cken  Frontend Developer
# 493         493  19-01-2021   26   Male        Berlin              DevOps
#
#      total_years_of_experience  years_of_experience_in_germany  \
# 489                       15.0                             5.0
# 490                       10.0                             5.0
# 491                        9.0                             5.0
# 492                        7.0                             7.0
# 493                        2.0                             2.0
#
#     seniority_level technical_language  ... bonus+stocks  \
# 489          Senior            Android  ...       1000.0
# 490            Head              Scala  ...          NaN
# 491          Senior               Java  ...      72000.0
# 492          Middle         JavaScript  ...      40950.0
# 493          Middle               yaml  ...       6500.0
#
#      annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 489                                            83000.0
# 490                                            80000.0
# 491                                            70000.0
# 492                                            33800.0
# 493                                            40000.0
#
#      bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 489                                             3500.0
# 490                                                NaN
# 491                                            72000.0
# 492                                            36400.0
# 493                                                NaN
#
#      vacation_days   employment_status   contract_duration main_language  \
# 489             29  Full-time employee  Unlimited contract       English
# 490             24  Full-time employee  Unlimited contract       English
# 491             26  Full-time employee  Unlimited contract       English
# 492             27  Full-time employee  Unlimited contract        German
# 493             30  Full-time employee  Unlimited contract       English
#
#     company_size company_type lost_job
# 489     101-1000      Product       No
# 490       Nov-50      Startup       No
# 491       51-100      Product      Yes
# 492     101-1000      Product       No
# 493       51-100      Startup       No
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 22 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Unnamed: 0                                                                     494 non-null    int64
#  1   timestamp                                                                      494 non-null    object
#  2   age                                                                            494 non-null    int64
#  3   gender                                                                         494 non-null    object
#  4   city                                                                           494 non-null    object
#  5   position                                                                       494 non-null    object
#  6   total_years_of_experience                                                      494 non-null    float64
#  7   years_of_experience_in_germany                                                 494 non-null    float64
#  8   seniority_level                                                                494 non-null    object
#  9   technical_language                                                             494 non-null    object
#  10  other_technical_language                                                       494 non-null    object
#  11  yearly_brutto_salary                                                           494 non-null    float64
#  12  bonus+stocks                                                                   345 non-null    float64
#  13  annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  493 non-null    float64
#  14  bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)              319 non-null    float64
#  15  vacation_days                                                                  494 non-null    object
#  16  employment_status                                                              494 non-null    object
#  17  contract_duration                                                              494 non-null    object
#  18  main_language                                                                  494 non-null    object
#  19  company_size                                                                   494 non-null    object
#  20  company_type                                                                   494 non-null    object
#  21  lost_job                                                                       494 non-null    object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 85.0+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         age  total_years_of_experience  \
# count  494.000000  494.000000                 494.000000
# mean   246.500000   32.925101                   9.288057
# std    142.749781    5.348737                   5.692242
# min      0.000000   22.000000                   0.000000
# 25%    123.250000   29.000000                   5.000000
# 50%    246.500000   33.000000                   9.000000
# 75%    369.750000   36.000000                  13.000000
# max    493.000000   56.000000                  31.000000
#
#        years_of_experience_in_germany  yearly_brutto_salary   bonus+stocks  \
# count                      494.000000            494.000000     345.000000
# mean                         4.340688          75324.858300   28316.249652
# std                          3.710260          42015.866759   35783.445320
# min                          0.000000          12000.000000      12.000000
# 25%                          2.000000          60000.000000    5000.000000
# 50%                          3.500000          72000.000000   10000.000000
# 75%                          5.750000          83000.000000   46000.000000
# max                         30.000000         850000.000000  200000.000000
#
#        annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# count                                         493.000000
# mean                                        67279.223124
# std                                         21406.825148
# min                                         11000.000000
# 25%                                         55000.000000
# 50%                                         66000.000000
# 75%                                         77000.000000
# max                                        200000.000000
#
#        bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)
# count                                         319.000000
# mean                                        31192.404389
# std                                         33498.983196
# min                                           100.000000
# 25%                                          5000.000000
# 50%                                         12000.000000
# 75%                                         59000.000000
# max                                        200000.000000

# %%
print(f"Rows : {df.shape[0]}")
print(f"Column : {df.shape[1]}")
# Out:
# Rows : 494
# Column : 22

# %%
print(f"\nAttributes:\n {df.columns.tolist()}")
# Out:
# Attributes:
#  ['Unnamed: 0', 'timestamp', 'age', 'gender', 'city', 'position', 'total_years_of_experience', 'years_of_experience_in_germany', 'seniority_level', 'technical_language', 'other_technical_language', 'yearly_brutto_salary', 'bonus+stocks', 'annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)', 'bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)', 'vacation_days', 'employment_status', 'contract_duration', 'main_language', 'company_size', 'company_type', 'lost_job']

# %%
print('Percentage of missing values : \n\n', (100*df.isnull().sum()/df.shape[0]).round(2))
# Out:
# Percentage of missing values :
#
#  Unnamed: 0                                                                        0.00
# timestamp                                                                         0.00
# age                                                                               0.00
# gender                                                                            0.00
# city                                                                              0.00
# position                                                                          0.00
# total_years_of_experience                                                         0.00
# years_of_experience_in_germany                                                    0.00
# seniority_level                                                                   0.00
# technical_language                                                                0.00
# other_technical_language                                                          0.00
# yearly_brutto_salary                                                              0.00
# bonus+stocks                                                                     30.16
# annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)     0.20
# bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)                35.43
# vacation_days                                                                     0.00
# employment_status                                                                 0.00
# contract_duration                                                                 0.00
# main_language                                                                     0.00
# company_size                                                                      0.00
# company_type                                                                      0.00
# lost_job                                                                          0.00
# dtype: float64

# %%
print('Unique values per column :\n\n',df.nunique())
# Out:
# Unique values per column :
#
#  Unnamed: 0                                                                       494
# timestamp                                                                         46
# age                                                                               31
# gender                                                                             3
# city                                                                              68
# position                                                                          72
# total_years_of_experience                                                         36
# years_of_experience_in_germany                                                    26
# seniority_level                                                                   10
# technical_language                                                               135
# other_technical_language                                                         317
# yearly_brutto_salary                                                             125
# bonus+stocks                                                                     105
# annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)    117
# bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)                107
# vacation_days                                                                     29
# employment_status                                                                  5
# contract_duration                                                                  3
# main_language                                                                     10
# company_size                                                                       5
# company_type                                                                      33
# lost_job                                                                           2
# dtype: int64

# %%
print(f'Percentage of duplicate records: {100-(100*df.drop_duplicates().shape[0]/df.shape[0])}')
# Out:
# Percentage of duplicate records: 0.0

# %%
fig, (ax_box,ax_hist) = plt.subplots(2,sharex=True,figsize=(15,8))

sns.boxplot(data=df,x='Age',ax=ax_box)
sns.histplot(data=df,x='Age',kde=True,ax=ax_hist)
plt.title("Age of survey participants distribution",fontsize=20)
plt.xticks(fontsize=13,rotation=90)
plt.xlabel("Different Age Participants",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Frequencies",fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12688/3621011354.py in <module>
#       1 fig, (ax_box,ax_hist) = plt.subplots(2,sharex=True,figsize=(15,8))
#       2
# ----> 3 sns.boxplot(data=df,x='Age',ax=ax_box)
#       4 sns.histplot(data=df,x='Age',kde=True,ax=ax_hist)
#       5 plt.title("Age of survey participants distribution",fontsize=20)
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Age'

# %%
fig, (ax_box,ax_hist) = plt.subplots(2,sharex=True,figsize=(15,8))

# %%
sns.boxplot(data=df,x='age',ax=ax_box)
sns.histplot(data=df,x='age',kde=True,ax=ax_hist)
plt.title("Age of survey participants distribution",fontsize=20)
plt.xticks(fontsize=13,rotation=90)
plt.xlabel("Different Age Participants",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Frequencies",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=df,x='gender')
plt.xticks(fontsize=13,rotation=90)
plt.xlabel("Gender",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Frequency",fontsize=14)
plt.title("Gender Participants",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df['city'].value_counts().head(10).reset_index(),
        y='index',x='city')
plt.xticks(fontsize=13)
plt.xlabel("Frequency",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("City",fontsize=14)
plt.title("Total Survey participants in different cities",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(15,8))

df['city'].value_counts().iloc[:5].plot.pie(autopct="%1.2f%%",fontsize=13,startangle=90,labels=['']*5,
cmap='Set2',explode=[0.05] * 5,pctdistance=1.2)
plt.ylabel("")
plt.legend(loc='upper left',labels=df['city'].value_counts().iloc[:5].index)
plt.title("Top Five City On The Survey",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='gender',y='age',data=df,palette='Pastel2')
plt.xticks(fontsize=13)
plt.xlabel("Gender",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Age",fontsize=14)
plt.title("Survey of Gender by Age",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(18,18))
sns.set_style('whitegrid')
sns.countplot(y='position', data=df)
plt.title("Different Job Position",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Different Job Position')

# %%
sns.set_style('whitegrid')
sns.countplot(y='seniority_level', hue='lost_job', data=df)
plt.title("who lost there Job?",fontsize=20)
plt.xlabel("Total number of people",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
# Out:
# Text(0, 0.5, 'Seniority level')

# %%
sns.set_style('whitegrid')
sns.countplot(y='seniority_level', data=df)
plt.xlabel("Total number of people",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
plt.title("Seniority level",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Seniority level')

# %%
df.columns = (df.columns.str.strip().str.lower()
              .str.replace(' ', '_')
               .str.replace('&','_'))
df.head()
# Out:
#    unnamed:_0   timestamp  age gender    city           position  \
# 0           0  24-11-2020   26   Male  Munich  Software Engineer
# 1           1  24-11-2020   29   Male  Berlin  Software Engineer
# 2           2  24-11-2020   32   Male  Berlin             DevOps
# 3           3  24-11-2020   34   Male  Berlin   Mobile Developer
# 4           4  24-11-2020   38   Male  Berlin          Team Lead
#
#    total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 0                        5.0                             3.0          Senior
# 1                       12.0                             6.0            Lead
# 2                        5.0                             1.0          Senior
# 3                       11.0                             5.0            Lead
# 4                       18.0                             4.0            Lead
#
#         technical_language  ... bonus+stocks  \
# 0               TypeScript  ...       5000.0
# 1  Javascript / Typescript  ...     120000.0
# 2     AWS, GCP, Python,K8s  ...       5000.0
# 3                   kotlin  ...      80000.0
# 4                      iOS  ...       4000.0
#
#    annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 0                                            75000.0
# 1                                           100000.0
# 2                                            76000.0
# 3                                            75000.0
# 4                                            80000.0
#
#    bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 0                                            10000.0
# 1                                           100000.0
# 2                                             5000.0
# 3                                            75000.0
# 4                                             2000.0
#
#    vacation_days           employment_status   contract_duration  \
# 0             30          Full-time employee  Unlimited contract
# 1             30  Self-employed (freelancer)  Temporary contract
# 2             30          Full-time employee  Unlimited contract
# 3             28          Full-time employee  Unlimited contract
# 4             28          Full-time employee  Unlimited contract
#
#   main_language company_size company_type lost_job
# 0       English       51-100      Product       No
# 1       English     101-1000      Product      Yes
# 2       English       Nov-50      Startup       No
# 3       English     101-1000      Product       No
# 4       English     101-1000      Product      Yes
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 22 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   unnamed:_0                                                                     494 non-null    int64
#  1   timestamp                                                                      494 non-null    object
#  2   age                                                                            494 non-null    int64
#  3   gender                                                                         494 non-null    object
#  4   city                                                                           494 non-null    object
#  5   position                                                                       494 non-null    object
#  6   total_years_of_experience                                                      494 non-null    float64
#  7   years_of_experience_in_germany                                                 494 non-null    float64
#  8   seniority_level                                                                494 non-null    object
#  9   technical_language                                                             494 non-null    object
#  10  other_technical_language                                                       494 non-null    object
#  11  yearly_brutto_salary                                                           494 non-null    float64
#  12  bonus+stocks                                                                   345 non-null    float64
#  13  annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  493 non-null    float64
#  14  bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)              319 non-null    float64
#  15  vacation_days                                                                  494 non-null    object
#  16  employment_status                                                              494 non-null    object
#  17  contract_duration                                                              494 non-null    object
#  18  main_language                                                                  494 non-null    object
#  19  company_size                                                                   494 non-null    object
#  20  company_type                                                                   494 non-null    object
#  21  lost_job                                                                       494 non-null    object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 85.0+ KB

# %%
df['yearly_brutto_salary'] = df['yearly_brutto_salary'].replace({'\€': '',',':''}, regex=True).astype(float)

# %%
df['bonus+stocks'] = df['bonus+stocks'].replace({'\€':'',',':'',' bvg only ':''}, regex=True)
df['bonus+stocks'] = pd.to_numeric(df['bonus+stocks'])

# %%
df['annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)'] = df['annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)'].replace({'\€':'',',':''}, regex=True)
df['annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)'] = pd.to_numeric(df['annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)'])

# %%
df['bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)'] = df['bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)'].replace({'\€':'',',':'',' learning budget bvg gym food ':''}, regex=True)
df['bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)'] = pd.to_numeric(df['bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 22 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   unnamed:_0                                                                     494 non-null    int64
#  1   timestamp                                                                      494 non-null    object
#  2   age                                                                            494 non-null    int64
#  3   gender                                                                         494 non-null    object
#  4   city                                                                           494 non-null    object
#  5   position                                                                       494 non-null    object
#  6   total_years_of_experience                                                      494 non-null    float64
#  7   years_of_experience_in_germany                                                 494 non-null    float64
#  8   seniority_level                                                                494 non-null    object
#  9   technical_language                                                             494 non-null    object
#  10  other_technical_language                                                       494 non-null    object
#  11  yearly_brutto_salary                                                           494 non-null    float64
#  12  bonus+stocks                                                                   345 non-null    float64
#  13  annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  493 non-null    float64
#  14  bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)              319 non-null    float64
#  15  vacation_days                                                                  494 non-null    object
#  16  employment_status                                                              494 non-null    object
#  17  contract_duration                                                              494 non-null    object
#  18  main_language                                                                  494 non-null    object
#  19  company_size                                                                   494 non-null    object
#  20  company_type                                                                   494 non-null    object
#  21  lost_job                                                                       494 non-null    object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 85.0+ KB

# %%
df.describe()
# Out:
#        unnamed:_0         age  total_years_of_experience  \
# count  494.000000  494.000000                 494.000000
# mean   246.500000   32.925101                   9.288057
# std    142.749781    5.348737                   5.692242
# min      0.000000   22.000000                   0.000000
# 25%    123.250000   29.000000                   5.000000
# 50%    246.500000   33.000000                   9.000000
# 75%    369.750000   36.000000                  13.000000
# max    493.000000   56.000000                  31.000000
#
#        years_of_experience_in_germany  yearly_brutto_salary   bonus+stocks  \
# count                      494.000000            494.000000     345.000000
# mean                         4.340688          75324.858300   28316.249652
# std                          3.710260          42015.866759   35783.445320
# min                          0.000000          12000.000000      12.000000
# 25%                          2.000000          60000.000000    5000.000000
# 50%                          3.500000          72000.000000   10000.000000
# 75%                          5.750000          83000.000000   46000.000000
# max                         30.000000         850000.000000  200000.000000
#
#        annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# count                                         493.000000
# mean                                        67279.223124
# std                                         21406.825148
# min                                         11000.000000
# 25%                                         55000.000000
# 50%                                         66000.000000
# 75%                                         77000.000000
# max                                        200000.000000
#
#        bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)
# count                                         319.000000
# mean                                        31192.404389
# std                                         33498.983196
# min                                           100.000000
# 25%                                          5000.000000
# 50%                                         12000.000000
# 75%                                         59000.000000
# max                                        200000.000000

# %%
df.to_csv('ITSalarySurveyEU.csv')

# %%
# violinplots show dependency of salary on the following features:
my_features = ['gender', 'seniority_level', 'AgeGroup']
for f in my_features:
    plt.style.use('seaborn-pastel')
    plt.figure(figsize=(12,5))
    sns.violinplot(data=df, x=f, y='yearly_brutto_salary')
    plt.grid()
    plt.title('Salary by ' + f)
    plt.show()

# %%
sns.set_style('whitegrid')
sns.barplot(x='technical_language', y='yearly_brutto_salary', data=df)
#plt.xlabel("Total number of people",fontsize=14)
#plt.ylabel("Seniority level",fontsize=14)
#plt.title("Seniority level",fontsize=20)
# Out:
# <AxesSubplot:xlabel='technical_language', ylabel='yearly_brutto_salary'>

# %%
# barplots show dependency of salary on the following features:
my_features = ['gender', 'seniority_level', 'AgeGroup']

for f in my_features:
    plt.style.use('seaborn-pastel')
    plt.figure(figsize=(12,5))
    sns.barplot(data=df, x=f, y='yearly_brutto_salary')
    plt.grid()
    plt.title('Salary by ' + f)
    plt.xlabel(f,fontsize=14)
    plt.ylabel("Yearly brutto salary",fontsize=14)
    plt.show()

# %%
# plot distributions of categorical features
features_cat = ['technical_language']
for f in features_cat:
    plt.figure(figsize=(14,5))
    val_c = df[f].value_counts()
    if len(val_c) <= 20:
        val_c.plot(kind='bar', color='lightgreen')
        plt.title(f)
    else: # if more than 20 levels show only the most frequent 20
        val_c[0:20].plot(kind='bar', color='lightgreen')
        plt.title(f + ' - Top 20 only')
        
    plt.grid()
    plt.show()

# %%
# alternative visualization: scatterplot salary vs age

features_cat = ['technical_language']
for f in features_cat:
    plt.figure(figsize=(14,5))
    val_c = df[f].value_counts()
    if len(val_c) >= 10:
        sns.jointplot(y=df['position'], x=df['yearly_brutto_salary'],
              height=10, color='green',
              joint_kws={'alpha' : 0.8})
plt.show()

# %%
features_cat = ['position']
for f in features_cat:
    plt.figure(figsize=(14,5))
    val_c = df[f].value_counts()
    if len(val_c) <= 20:
        val_c.plot(kind='bar', color='lightgreen')
        plt.title(f)
    else: # if more than 20 levels show only the most frequent 20
        val_c[0:20].plot(kind='bar', color='lightgreen')
        plt.title("Position - Top 20 only", fontsize= 20)
        plt.xlabel("Positions")
        plt.ylabel("Count")
    plt.grid()
    plt.show()

# %%
# select Software Engineer only
df_ds = df[df.position=='Software Engineer'].copy()
df_ds.head()
# Out:
#    unnamed:_0   timestamp  age gender                city           position  \
# 0           0  24-11-2020   26   Male              Munich  Software Engineer
# 1           1  24-11-2020   29   Male              Berlin  Software Engineer
# 6           6  24-11-2020   30   Male              Berlin  Software Engineer
# 7           7  24-11-2020   34   Male              Munich  Software Engineer
# 8           8  24-11-2020   45   Male  Schleswig-Holstein  Software Engineer
#
#    total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 0                        5.0                             3.0          Senior
# 1                       12.0                             6.0            Lead
# 6                        6.0                             3.0          Senior
# 7                       13.0                             3.0            Lead
# 8                       26.0                            18.0          Senior
#
#         technical_language  ...  \
# 0               TypeScript  ...
# 1  Javascript / Typescript  ...
# 6                     Java  ...
# 7                     .NET  ...
# 8                       C#  ...
#
#   annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 0                                            75000.0
# 1                                           100000.0
# 6                                            54000.0
# 7                                            60000.0
# 8                                            93000.0
#
#    bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 0                                            10000.0
# 1                                           100000.0
# 6                                            54000.0
# 7                                            60000.0
# 8                                            11000.0
#
#    vacation_days           employment_status   contract_duration  \
# 0             30          Full-time employee  Unlimited contract
# 1             30  Self-employed (freelancer)  Temporary contract
# 6             27          Full-time employee  Unlimited contract
# 7             30          Full-time employee  Unlimited contract
# 8             30          Full-time employee  Unlimited contract
#
#   main_language company_size company_type lost_job  AgeGroup
# 0       English       51-100      Product       No  (25, 30]
# 1       English     101-1000      Product      Yes  (25, 30]
# 6       English        1000+      Product       No  (25, 30]
# 7       English       51-100      Product       No  (30, 35]
# 8        German        1000+      Product       No  (40, 45]
#
# [5 rows x 23 columns]

# %%
# select Backend Developer only
df_ds = df[df.position=='Backend Developer'].copy()
df_ds.head()
# Out:
#     unnamed:_0   timestamp  age gender    city           position  \
# 19          19  24-11-2020   37   Male  Munich  Backend Developer
# 22          22  24-11-2020   30   Male  Berlin  Backend Developer
# 28          28  24-11-2020   28   Male  Munich  Backend Developer
# 31          31  24-11-2020   36   Male  Berlin  Backend Developer
# 48          48  24-11-2020   33   Male  Munich  Backend Developer
#
#     total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 19                       12.0                             4.0          Senior
# 22                        6.0                             2.0          Senior
# 28                        6.0                             5.0          Senior
# 31                       18.0                             1.0          Senior
# 48                       15.0                             3.0            Lead
#
#    technical_language  ...  \
# 19                php  ...
# 22               Ruby  ...
# 28               Java  ...
# 31                PHP  ...
# 48              Scala  ...
#
#    annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 19                                            60000.0
# 22                                            65000.0
# 28                                            57000.0
# 31                                            60000.0
# 48                                            98000.0
#
#     bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 19                                             5000.0
# 22                                            65000.0
# 28                                             1500.0
# 31                                            60000.0
# 48                                              101.0
#
#     vacation_days   employment_status   contract_duration main_language  \
# 19             28  Full-time employee  Unlimited contract       English
# 22             30  Full-time employee  Unlimited contract       English
# 28             30  Full-time employee  Unlimited contract       English
# 31             26  Full-time employee  Unlimited contract       English
# 48             30  Full-time employee  Unlimited contract       English
#
#    company_size         company_type lost_job  AgeGroup
# 19     101-1000              Product       No  (35, 40]
# 22     101-1000              Product       No  (25, 30]
# 28     101-1000  Consulting / Agency       No  (25, 30]
# 31     101-1000              Product       No  (35, 40]
# 48       Nov-50              Startup       No  (30, 35]
#
# [5 rows x 23 columns]

# %%
# select data scientists only
df_ds = df[df.position=='Data Scientist'].copy()
df_ds.head()
# Out:
#     unnamed:_0   timestamp  age  gender    city        position  \
# 5            5  24-11-2020   33    Male  Berlin  Data Scientist
# 10          10  24-11-2020   26  Female  Munich  Data Scientist
# 11          11  24-11-2020   24    Male  Berlin  Data Scientist
# 15          15  24-11-2020   26    Male  Munich  Data Scientist
# 32          32  24-11-2020   31    Male  Berlin  Data Scientist
#
#     total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 5                         5.0                             4.0            Lead
# 10                        6.0                             2.0          Middle
# 11                        4.0                             2.0          Senior
# 15                        3.0                             2.0          Middle
# 32                       10.0                             5.0            Lead
#
#    technical_language  ...  \
# 5              Python  ...
# 10             python  ...
# 11             Python  ...
# 15             Python  ...
# 32            Python   ...
#
#    annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 5                                             81000.0
# 10                                            60000.0
# 11                                            50000.0
# 15                                            52000.0
# 32                                           115000.0
#
#     bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 5                                              4000.0
# 10                                            60000.0
# 11                                            50000.0
# 15                                              300.0
# 32                                            60000.0
#
#     vacation_days   employment_status   contract_duration main_language  \
# 5              24  Full-time employee  Unlimited contract       English
# 10             26  Full-time employee  Unlimited contract       English
# 11             24  Full-time employee  Unlimited contract       English
# 15             30  Full-time employee  Unlimited contract       English
# 32             28  Full-time employee  Unlimited contract       English
#
#    company_size company_type lost_job  AgeGroup
# 5         1000+      Product       No  (30, 35]
# 10        1000+      Product       No  (25, 30]
# 11     101-1000      Startup       No  (20, 25]
# 15     101-1000      Product       No  (25, 30]
# 32        1000+      Product       No  (30, 35]
#
# [5 rows x 23 columns]

# %%
# select Frontend Developer only
df_ds = df[df.position=='Frontend Developer'].copy()
df_ds.head()
# Out:
#      unnamed:_0   timestamp  age  gender       city            position  \
# 27           27  24-11-2020   31    Male     Berlin  Frontend Developer
# 68           68  24-11-2020   35  Female     Berlin  Frontend Developer
# 69           69  24-11-2020   34    Male     Berlin  Frontend Developer
# 75           75  24-11-2020   30    Male     Munich  Frontend Developer
# 111         111  24-11-2020   24    Male  Frankfurt  Frontend Developer
#
#      total_years_of_experience  years_of_experience_in_germany  \
# 27                        10.0                             1.5
# 68                        12.0                             5.0
# 69                        10.0                             3.0
# 75                         9.0                             3.0
# 111                        3.0                             0.0
#
#     seniority_level technical_language  ...  \
# 27           Senior         Javascript  ...
# 68           Middle        Javascript   ...
# 69           Senior     Angular, React  ...
# 75           Middle         TypeScript  ...
# 111          Middle         JavaScript  ...
#
#     annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 27                                             67500.0
# 68                                             70000.0
# 69                                             68000.0
# 75                                             64000.0
# 111                                            44000.0
#
#      bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 27                                               101.0
# 68                                                 NaN
# 69                                                 NaN
# 75                                                 NaN
# 111                                                NaN
#
#      vacation_days   employment_status   contract_duration main_language  \
# 27              28  Full-time employee  Unlimited contract       English
# 68              29  Full-time employee  Unlimited contract       English
# 69              40  Full-time employee  Unlimited contract       English
# 75              30  Full-time employee  Unlimited contract       English
# 111             26  Full-time employee  Unlimited contract       English
#
#     company_size company_type lost_job  AgeGroup
# 27        51-100      Startup       No  (30, 35]
# 68      101-1000   E-commerce       No  (30, 35]
# 69        Nov-50      Startup       No  (30, 35]
# 75      101-1000      Product       No  (25, 30]
# 111       51-100      Product       No  (20, 25]
#
# [5 rows x 23 columns]

# %%
# select QA Engineer only
df_ds = df[df.position=='QA Engineer'].copy()
df_ds.head()
# Out:
#     unnamed:_0   timestamp  age  gender    city     position  \
# 13          13  24-11-2020   27    Male  Munich  QA Engineer
# 21          21  24-11-2020   34    Male  Berlin  QA Engineer
# 30          30  24-11-2020   46    Male  Munich  QA Engineer
# 34          34  24-11-2020   30  Female  Berlin  QA Engineer
# 41          41  24-11-2020   36  Female  Berlin  QA Engineer
#
#     total_years_of_experience  years_of_experience_in_germany seniority_level  \
# 13                        5.0                             1.0          Senior
# 21                       10.0                             4.0          Senior
# 30                       13.0                            13.0          Senior
# 34                        5.0                             3.0          Middle
# 41                       14.0                             7.0            Lead
#
#    technical_language  ...  \
# 13              Swift  ...
# 21               Java  ...
# 30               Java  ...
# 34            Python   ...
# 41               Java  ...
#
#    annual_brutto_salary_one_year_ago(only_answer_if_staying_in_the_same_country)  \
# 13                                            58000.0
# 21                                            65000.0
# 30                                            70000.0
# 34                                            50000.0
# 41                                            63000.0
#
#     bonus+stocks_one_year_ago(only_answer_if_staying_in_same_country)  \
# 13                                              101.0
# 21                                             3000.0
# 30                                             8500.0
# 34                                             4000.0
# 41                                             6300.0
#
#     vacation_days   employment_status   contract_duration main_language  \
# 13             30  Full-time employee  Unlimited contract       English
# 21             28  Full-time employee  Unlimited contract       English
# 30             28  Full-time employee  Unlimited contract        German
# 34             30  Full-time employee  Unlimited contract        German
# 41             30  Full-time employee  Unlimited contract       English
#
#    company_size company_type lost_job  AgeGroup
# 13        1000+      Product       No  (25, 30]
# 21     101-1000      Startup       No  (30, 35]
# 30     101-1000      Product       No  (45, 50]
# 34     101-1000      Product       No  (25, 30]
# 41       Nov-50      Product       No  (35, 40]
#
# [5 rows x 23 columns]

# %%
# create wordcloud fpr main tech/progamming language
import sys
print(sys.executable)
# Out:
# C:\JupyterLab\resources\jlab_server\python.exe

# %%
pip install  WordCloud
# Out:
# Collecting WordCloud
#   Downloading wordcloud-1.8.1-cp38-cp38-win_amd64.whl (155 kB)
# Requirement already satisfied: pillow in c:\jupyterlab\resources\jlab_server\lib\site-packages (from WordCloud) (8.3.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from WordCloud) (1.21.3)
# Requirement already satisfied: matplotlib in c:\jupyterlab\resources\jlab_server\lib\site-packages (from WordCloud) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from matplotlib->WordCloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from matplotlib->WordCloud) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# create wordcloud fpr main tech/progamming language
f = 'technical_language'
text_select = df[f][df[f] != 'MISSING']
text = " ".join(txt for txt in text_select)

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, max_font_size=100, max_words=500,
                      width = 800, height = 600,
                      background_color='black').generate(text)

plt.figure(figsize=(11,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sns.set_style('whitegrid')
sns.barplot(x='total_years_of_experience', y='seniority_level', data=df)
plt.xlabel("Total_years_of_experience",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
plt.title("Seniority level by total years of experience",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Seniority level by total years of experience')

# %%
sns.set_style('whitegrid')
sns.countplot(y='seniority_level', data=df)
plt.xlabel("Total number of people",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
plt.title("Seniority level",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Seniority level')

# %%
sns.set_style('whitegrid')
sns.barplot(y='position', x='age', data=df)
sns.set({'figure.figsize':(11.27,8.27)})
plt.xlabel("age",fontsize=14)
plt.legend(loc='upper left',labels=df['position'].value_counts().iloc[:5].index)
plt.ylabel("position",fontsize=14)
plt.title("position by age",fontsize=20)
# Out:
# Text(0.5, 1.0, 'position by age')
